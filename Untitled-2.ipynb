# %% [markdown]
# # Spread analysis
#
# Segment cells and measure the spread of the intensity in each channel
#
#
# To run the nodebook on a cluster
# ```
# ssh hex
# srun --partition gpu --gres=gpu:rtx2080ti -c 64 --pty bash -i
# source miniconda3/bin/activate
# conda activate imaging
# jupyter lab --no-browser  --NotebookApp.allow_origin='*' --NotebookApp.ip='0.0.0.0'
# ```

# %%
import socket
socket.gethostname()
# Out:
# 'DESKTOP-6J9I8HE'

# %%
from pathlib import Path
import tifffile 
from cellpose import models, core 
from skimage.measure import regionprops
from skimage.measure import find_contours
from skimage import morphology
import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt


print('Using GPU', core.use_gpu())

def does_not_touch_image_border(prop, shape):
    """Return true if the roi does not touch the image border defined by the shape [ny,nx]"""  
    if len(prop.bbox) != 4:
        print('prop has not 4 elements')
    return (prop.bbox[0] > 0) and (prop.bbox[1] > 0) and (prop.bbox[2] < shape[1] and prop.bbox[3] < shape[0])    

def spatial_spread(prop, image):
    """Spread as the trace of the moment matrix in a region"""
    x,y = np.meshgrid(         
        np.arange(prop.bbox[1],prop.bbox[3]),
        np.arange(prop.bbox[0],prop.bbox[2]))    
    image = image[:,prop.bbox[0]:prop.bbox[2], prop.bbox[1]:prop.bbox[3]]
    L = []
    for weight in image:
        w = weight * prop.image
        if (w.max()-w.min()) > 0 :
            w = (w - w.min()) / (w.max() - w.min())
        else:
            return 0
        sw = np.sum(w)
        if sw < 1e-9:
            return 0.0
        sx = np.sum(w * x) / sw
        sy = np.sum(w * y) / sw
        sxx = np.sum(w * np.square(x-sx)) / sw
        syy = np.sum(w * np.square(y-sy)) / sw
        #sxy = np.sum(w * (x-sx) * (y-sy)) / sw
        L.append(np.sqrt(sxx + syy))
    return L


def measure_spread_in_image(model, img, channels):
    print('segment')
    mask = model.eval(
            img,
            channel_axis = 0, 
            channels = [channels['cells']+1, channels['nuclei']+1],
            diameter = 200, 
            flow_threshold = -1, 
            cellprob_threshold = 0.0, # default is 0
            min_size = 10 # filter out smaller cells
        )[0]

    print('regions')
    props = regionprops(mask)
    props = [x for x in props if does_not_touch_image_border(x, img.shape[1:3])]

    print('spread')
    se = morphology.disk(30)

    signal = np.stack([morphology.white_tophat(ch, se) for ch in img])

    spread = np.array([spatial_spread(p, signal) for p in props])        

    tmp =  pd.DataFrame({
        
        'Cell': np.arange(len(props)),
        'Area': [x.area for x in props]
        })
    
    for k, c in enumerate(channels):
        tmp['spread [' + c + ']'] = spread[:,k] 

    return tmp, props    

def measure_spread_in_cells(filename, channels):
    imglist = tifffile.imread(filename)
    model = models.Cellpose(gpu=core.use_gpu(), model_type='cyto2')
    df = []
    rois = [] * len(imglist)
    for idx, img in enumerate(imglist):
        tmp, props = measure_spread_in_image(model, img, channels)
        tmp['Filename'] = [filename] * len(props)
        tmp['Image'] = [ idx ] * len(props)
        df.append(tmp)
        rois[idx] = props
        
    return pd.concat(df), rois

def visualize(img, rois, df):
    from matplotlib.patches import Ellipse        
    plt.imshow(img[0])
    for r in rois:
        c = find_contours(np.pad(r.image,1) > 0, 0.5)
        plt.plot(c[0][:,1] + r.bbox[0], c[0][:,0] + r.bbox[1])
        #ellipse = Ellipse((p.centroid[0], p.centroid[1]), width = df
    plt.axis('off')
# Out:
# Using GPU True

# %% [markdown]
# Choose a folder containing the lsm files to analyse

# %%
from ipyfilechooser import FileChooser
#basefolder = '/cephfs2/jeromeb/userdata/Bullock_group/Lucas/'
basefolder = '/media/cephfs2/userdata/Bullock_group/Lucas/'
fc = FileChooser(basefolder) 
display(fc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ipyfilechooser import FileChooser
#       2 #basefolder = '/cephfs2/jeromeb/userdata/Bullock_group/Lucas/'
#       3 basefolder = '/media/cephfs2/userdata/Bullock_group/Lucas/'
#
# ModuleNotFoundError: No module named 'ipyfilechooser'

# %%
from pathlib import Path
#folder = Path(fc.value)
folder = Path('/media/cephfs2/userdata/Bullock_group/Lucas/EXP.M20230114/')
#folder = Path('C:/Users/jerome/Downloads')
channels = {'nuclei':0,'cells':1,'label1':0,'label2':2}
filelist = pd.DataFrame({'Filename' : [str(x) for x in folder.glob('*.lsm')]})
filename = filelist['Filename'][1]
filename
imglist = tifffile.imread(filename)
img = imglist[0]

# %%
import tifffile 
from cellpose import models, core 
from skimage.measure import regionprops
from skimage.measure import find_contours
from skimage import morphology
import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

def segment_cells(img,type=0):
    print('segment')
    from scipy.ndimage import distance_transform_edt, median_filter,label
    from skimage.segmentation import watershed
    if type == 0:
        model = models.Cellpose(gpu=core.use_gpu(), model_type='nuclei')    
        nlabels = model.eval(
                img,
                channel_axis = 0, 
                channels = [1,0],
                diameter = 250, 
                flow_threshold = 0.4, 
                cellprob_threshold = 0.1, # default is 0
                min_size = 100000 # filter out smaller cells
            )[0]                                        
        dist = distance_transform_edt(nlabels > 0)
        mask = median_filter(np.amax(img,0), 11)
        mask = mask > mask[mask < np.quantile(mask, 0.1)].mean()
        clabels = watershed(-dist, nlabels, mask=mask)            
    else :
        model = models.Cellpose(gpu=core.use_gpu(), model_type='cyto2')    
        clabels = model.eval(
                img,
                channel_axis = 0,
                channels = [1,4],
                diameter = 250, 
                flow_threshold = 0.4, 
                cellprob_threshold = 0.1, # default is 0
                min_size = 100000 # filter out smaller cells
            )[0]             
    props = regionprops(clabels)                             
    props = [x for x in props if does_not_touch_image_border(x, img.shape[1:3])]
    #props = [x for x in props if x.area > 10000]
    return props

def visualize(img, rois, s=None):
    from matplotlib.patches import Circle
    #plt.imshow(img[[2,1,0]].swapaxes(0,-1))
    plt.imshow(img[0])
    for k,r in enumerate(rois):
        c = find_contours(np.pad(r.image,1) > 0, 0.5)
        plt.plot(c[0][:,1] + r.bbox[1], c[0][:,0] + r.bbox[0]) 
        if s is not None:
            c=plt.Circle((r.centroid[0], r.centroid[1]), s[k], fill=False)            
            plt.gca().add_patch(c)
    plt.axis('off')


roi = segment_cells(img,1)
visualize(img, roi)
# Out:
# segment

# %%
from scipy.ndimage import minimum_filter, maximum_filter, gaussian_filter
def spatial_spread(prop, image):
    """Spread as the trace of the moment matrix in a region
    Result
    ------
    list of tupe (centroid x, centroid y, sxx, sxy, syy) for each channel
    """
    y,x = np.meshgrid(         
        np.arange(prop.bbox[0],prop.bbox[2]),
        np.arange(prop.bbox[1],prop.bbox[3]),indexing='ij')    
    image = image[:,prop.bbox[0]:prop.bbox[2], prop.bbox[1]:prop.bbox[3]]
    S = []        
    for weight in image:
        w = weight *(weight>(weight.mean() + weight.std())) * prop.image        
        if (w.max()-w.min()) > 0 :
            w = (w - w.min()) / (w.max() - w.min())
        else:
            w = prop.image
        sw = np.sum(w)
        if sw < 1e-9:
            return 0.0
        sx = np.sum(w * x) / sw
        sy = np.sum(w * y) / sw
        sxx = np.sum(w * np.square(x-sx)) / sw
        syy = np.sum(w * np.square(y-sy)) / sw
        sxy = np.sum(w * (x-sx) * (y-sy)) / sw
        S.append((sx,sy,sxx,sxy,syy))              
    return S

signal = np.stack([gaussian_filter(ch, 10) for ch in img])
S = np.array([spatial_spread(x, signal) for x in roi ])

# %%
def visualize(img, rois, s=None):
    from matplotlib.patches import Circle    
    import math
    plt.imshow(img,cmap='gray')
    for k,r in enumerate(rois):
        c = find_contours(np.pad(r.image,1) > 0, 0.5)
        plt.plot(c[0][:,1] + r.bbox[1], c[0][:,0] + r.bbox[0]) 
        if s is not None:
            c = plt.Circle((s[k,0], s[k,1]), math.sqrt(s[k,2]+s[k,4]), fill=False,color='red',alpha=0.5)            
            plt.gca().add_patch(c)
    plt.axis('off') 
visualize(signal[3], roi, S[:,3,:])

# %%
from matplotlib.patches import Circle
fig,ax = plt.subplots(1)
ax.imshow(img[1])
for p in roi:    
    c = find_contours(p.image, 0.5)
    r = spatial_spread(p,img;)
    circle = Circle((p.centroid[1], p.centroid[0]), r, fill=False)
    ax.add_patch(circle)
    for cc in c:
        ax.plot(p.bbox[1]+cc[:,1],p.bbox[0]+cc[:,0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 8
#       6 r = spatial_spread(p,img.astype(float))
#       7 circle = Circle((p.centroid[1], p.centroid[0]), r, fill=False)
# ----> 8 ax.add_patch(circle)
#       9 for cc in c:
#      10     ax.plot(p.bbox[1]+cc[:,1],p.bbox[0]+cc[:,0])
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/matplotlib/axes/_base.py:2415, in _AxesBase.add_patch(self, p)
#    2413 if p.get_clip_path() is None:
#    2414     p.set_clip_path(self.patch)
# -> 2415 self._update_patch_limits(p)
#    2416 self._children.append(p)
#    2417 p._remove_method = self._children.remove
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/matplotlib/axes/_base.py:2446, in _AxesBase._update_patch_limits(self, patch)
#    2443 if len(vertices):
#    2444     vertices = np.row_stack(vertices)
# -> 2446 patch_trf = patch.get_transform()
#    2447 updatex, updatey = patch_trf.contains_branch_seperately(self.transData)
#    2448 if not (updatex or updatey):
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/matplotlib/patches.py:262, in Patch.get_transform(self)
#     260 def get_transform(self):
#     261     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 262     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/matplotlib/patches.py:1585, in Ellipse.get_patch_transform(self)
#    1584 def get_patch_transform(self):
# -> 1585     self._recompute_transform()
#    1586     return self._patch_transform
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/matplotlib/patches.py:1575, in Ellipse._recompute_transform(self)
#    1572 width = self.convert_xunits(self._width)
#    1573 height = self.convert_yunits(self._height)
#    1574 self._patch_transform = transforms.Affine2D() \
# -> 1575     .scale(width * 0.5, height * 0.5 * self._aspect_ratio_correction) \
#    1576     .rotate_deg(self.angle) \
#    1577     .scale(1, 1 / self._aspect_ratio_correction) \
#    1578     .translate(*center)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
result = []
for file in filelist['Filename']:    
    result.append(measure_spread_in_cells(file,channels))

result = pd.concat(result)

# %% [markdown]
# # Distributed computing

# %%
from dask_jobqueue import SLURMCluster
from dask.distributed import Client, progress
cluster = SLURMCluster(
     cores=1,       # size of a single job
     memory='64GB', # for a single job
     shebang='#!/usr/bin/env bash',
     processes=1,   # number of python process per job
     queue='gpu',      # cpu,gpu or ml
     job_extra=['--gres=gpu:gtx1080ti'],
     local_directory='/ssd',               
     walltime='02:00:00', # 2 hours wall time
)
cluster.adapt(maximum_jobs=2)
client = Client(cluster)
client
# Out:
# /lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43711 instead
#   warnings.warn(
# <Client: 'tcp://10.1.0.29:37675' processes=0 threads=0, memory=0 B>

# %%
import dask
tsk = [dask.delayed(measure_spread_in_cells)(file, channels) for file in filelist['Filename']]
result = dask.compute(tsk)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 import dask
#       2 tsk = [dask.delayed(measure_spread_in_cells)(file, channels) for file in filelist['Filename']]
# ----> 3 result = dask.compute(tsk)
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/client.py:3168, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3166         should_rejoin = False
#    3167 try:
# -> 3168     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3169 finally:
#    3170     for f in futures.values():
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/client.py:2328, in Client.gather(self, futures, errors, direct, asynchronous)
#    2326 else:
#    2327     local_worker = None
# -> 2328 return self.sync(
#    2329     self._gather,
#    2330     futures,
#    2331     errors=errors,
#    2332     direct=direct,
#    2333     local_worker=local_worker,
#    2334     asynchronous=asynchronous,
#    2335 )
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/utils.py:345, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     343     return future
#     344 else:
# --> 345     return sync(
#     346         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     347     )
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/utils.py:408, in sync(loop, func, callback_timeout, *args, **kwargs)
#     406 else:
#     407     while not e.is_set():
# --> 408         wait(10)
#     410 if error:
#     411     typ, exc, tb = error
#
# File ~/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/utils.py:397, in sync.<locals>.wait(timeout)
#     395 def wait(timeout):
#     396     try:
# --> 397         return e.wait(timeout)
#     398     except KeyboardInterrupt:
#     399         loop.add_callback(cancel)
#
# File ~/miniconda3/envs/imaging/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/miniconda3/envs/imaging/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Task exception was never retrieved
# future: <Task finished name='Task-3486' coro=<Client._gather.<locals>.wait() done, defined at /lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/client.py:2156> exception=AllExit()>
# Traceback (most recent call last):
#   File "/lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/client.py", line 2165, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-3487' coro=<Client._gather.<locals>.wait() done, defined at /lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/client.py:2156> exception=AllExit()>
# Traceback (most recent call last):
#   File "/lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/distributed/client.py", line 2165, in wait
#     raise AllExit()
# distributed.client.AllExit
# /lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)

# %%
cluster.scale(0)
# Out:
# /lmb/home/jeromeb/miniconda3/envs/imaging/lib/python3.9/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)

# %%
df = pd.concat([x[0] for x in result ])
filelist['Condition'][1] = 'As'
df = df.merge(filelist,on='Filename')
df
# Out:
#                                               Filename  FOV  Cell    Area  \
# 0    /media/cephfs2/userdata/Bullock_group/Lucas/EX...    0     0   69042
# 1    /media/cephfs2/userdata/Bullock_group/Lucas/EX...    0     1   50356
# 2    /media/cephfs2/userdata/Bullock_group/Lucas/EX...    0     2   77603
# 3    /media/cephfs2/userdata/Bullock_group/Lucas/EX...    0     3  157879
# 4    /media/cephfs2/userdata/Bullock_group/Lucas/EX...    0     4   35463
# ..                                                 ...  ...   ...     ...
# 269  /media/cephfs2/userdata/Bullock_group/Lucas/EX...    4    16   96314
# 270  /media/cephfs2/userdata/Bullock_group/Lucas/EX...    4    17   39412
# 271  /media/cephfs2/userdata/Bullock_group/Lucas/EX...    4    18   46492
# 272  /media/cephfs2/userdata/Bullock_group/Lucas/EX...    4    19  123727
# 273  /media/cephfs2/userdata/Bullock_group/Lucas/EX...    4    20   80171
#
#      spread [nuclei]  spread [cells]  spread [label1]  spread [label2]  \
# 0          94.511973      106.334725       108.124796        89.571046
# 1          78.092217       90.264263        91.740664        78.304048
# 2         103.555297      112.089061       113.162596        97.406787
# 3         157.160216      169.040084       171.445292       146.122425
# 4          73.206443       84.568953        84.028856        75.307843
# ..               ...             ...              ...              ...
# 269       123.829337      134.245758       136.534820       118.191047
# 270        70.414529       81.092990        81.117565        74.305055
# 271        87.173410       98.340757       100.000968        89.039252
# 272       139.547601      147.328690       150.676487       126.864381
# 273       109.070102      123.361135       123.944782       109.282085
#
#     Condition
# 0        ctrl
# 1        ctrl
# 2        ctrl
# 3        ctrl
# 4        ctrl
# ..        ...
# 269        As
# 270        As
# 271        As
# 272        As
# 273        As
#
# [274 rows x 9 columns]

# %%
df.boxplot(by='Condition', column='spread [cells]')
# Out:
# <AxesSubplot: title={'center': 'spread [cells]'}, xlabel='Condition'>
